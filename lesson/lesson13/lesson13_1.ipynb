# %%
import matplotlib.pyplot as plt

fig=plt.figure()

axes=fig.add_subplot(1,1,1)
x=[2,4,6]
y=[4,5,6]

axes.plot(x,y)
axes.set_title('title')
plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'chinese':78, 'english': 80, 'history':75, 'discover': 85}
student2 = {'chinese':69, 'english': 92, 'history':69, 'discover': 80}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure()
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,label='stu1',marker='o',markersize='20')
axes.plot(subjects,scores2,label='stu2',marker='o',markersize='20')
axes.legend()
plt.show()
